# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, BatchNormalization, SpatialDropout2D, Input, MaxPool2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import vgg16
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.data import Dataset, AUTOTUNE
import tensorflow.strings
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt

from glob import glob
from pathlib import Path
import os
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
PATH_TO_TRAINING = r'../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/'
PATH_TO_TRAINING_TENSOR = tf.Variable(PATH_TO_TRAINING)

TRAIN_GLAUCOMA_IMAGES = np.array(glob(os.path.join(PATH_TO_TRAINING, 'Images/GLAUCOMA/*')))
TRAIN_NORMAL_IMAGES = np.array(glob(os.path.join(PATH_TO_TRAINING, 'Images/NORMAL/*')))

TRAIN_GLAUCOMA_GT = np.array(glob(PATH_TO_TRAINING + '/GT/GALUCOMA/*'))
TRAIN_NORMAL_GT = np.array(glob(PATH_TO_TRAINING + '/GT/NORMAL/*'))

PATH_TO_TEST = r'../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test'
TEST_GLAUCOMA_IMAGES = np.array(glob(os.path.join(PATH_TO_TEST, 'Images/glaucoma/*')))
TEST_NORMAL_IMAGES = np.array(glob(os.path.join(PATH_TO_TEST, 'Images/normal/*')))

SEED = 2
EPSILON = 10 ** -4
STATELESS_RNG= tf.random.Generator.from_seed(SEED, alg='philox')
IMAGE_SIZE = (224, 224)
CHANNELS = 3
SHUFFLE_BUFFER = len(TRAIN_NORMAL_IMAGES) + len(TRAIN_GLAUCOMA_IMAGES)
BATCH_SIZE = SHUFFLE_BUFFER // 2
early_stopping = EarlyStopping(monitor = 'val_loss', restore_best_weights = True, patience = 5)

# %%
#.stem ===> instead of image1.jpg
Path(TRAIN_GLAUCOMA_IMAGES[0]).stem
TEST_GLAUCOMA_IMAGES
# Out:
# array(['../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_054.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_048.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_071.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_006.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_079.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_003.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_083.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_014.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_039.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_025.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_043.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_065.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_027.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_050.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_001.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_030.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_021.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_020.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_067.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_056.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_087.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_019.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_086.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_023.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_011.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_052.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_077.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_005.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_074.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_082.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_034.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_070.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_029.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_059.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_028.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_053.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_073.png',
#        '../input/drishtigs-retina-dataset-for-onh-segmentation/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_055.png'],
#       dtype='<U119')

# %%
def load_image_and_gt(path, test = False):
    '''
    Takes a path to the image,
    and returns the image alongside
    its ground truth
    '''
    
    print(path)
    
    filename = Path(path).stem
    if test:
        path_to_OD_softmap = os.path.join(PATH_TO_TEST, 'Test_GT', filename, 'SoftMap', filename + '_ODsegSoftmap.png')
        path_to_cup_softmap = os.path.join(PATH_TO_TEST, 'Test_GT', filename, 'SoftMap', filename + '_cupsegSoftmap.png')    
    else:
        path_to_OD_softmap = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'SoftMap', filename + '_ODsegSoftmap.png')
        path_to_cup_softmap = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'SoftMap', filename + '_cupsegSoftmap.png')
    image = tf.io.read_file(path)
    image = tf.io.decode_png(image)
    od = tf.io.read_file(path_to_OD_softmap)
    od = tf.io.decode_png(od)
    cup = tf.io.read_file(path_to_cup_softmap)
    cup = tf.io.decode_png(cup)
    return image, od, cup

def show_image_with_masks(image, od, cup, ax, index, label):
    '''
    Plots the real world image
    And the two masks
    Also shows the image after
    being masked with each mask
    Requires len(ax) >= 5
    '''
    ax[5 * index].imshow(image)
    ax[5 * index].set_title(label)
    ax[5 * index + 1].imshow(od)
    ax[5 * index + 1].set_title('Optical Disk Mask')
    ax[5 * index + 2].imshow(od * image)
    ax[5 * index + 2].set_title('Image with OD Mask')
    ax[5 * index + 3].imshow(cup)
    ax[5 * index + 3].set_title('Cup Mask')
    ax[5 * index + 4].imshow(cup * image)
    ax[5 * index + 4].set_title('Image with CUP Mask')
    
def load_image_with_masks(path, dice = False, test = False):
    '''
    This is similar to the
    load image_with_gt function
    however uses pure tf functions
    for the use in datasets
    otherwise I'd have to run
    in eagerexecution
    '''
    
    filename = tf.strings.split(path, sep = '.')[-2]
    filename = tf.strings.split(filename, sep = '/')[-1]
    directory_path = tf.strings.split(path, sep = 'Images')[0]
    if test:
        softmap_path = tf.strings.join([directory_path, 'Test_GT/', filename, '/SoftMap/'])
    else:
        softmap_path = tf.strings.join([directory_path, 'GT/', filename, '/SoftMap/'])
    od_path = tf.strings.join([softmap_path, filename, '_ODsegSoftmap.png'])
    cup_path = tf.strings.join([softmap_path, filename, '_cupsegSoftmap.png'])
    image = tf.io.read_file(path)
    image = tf.io.decode_png(image, channels = 3)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = image / 255.0
    
    od = tf.io.read_file(od_path)
    od = tf.io.decode_png(od, channels = 1)
    od = tf.image.resize(od, IMAGE_SIZE)
    od = od / 255.0
    if dice:
        od = tf.where(od >= 0.5, 1.0, 0.0)
    
    cup = tf.io.read_file(cup_path)
    cup = tf.io.decode_png(cup, channels = 1)
    cup = tf.image.resize(cup, IMAGE_SIZE)
    cup = cup / 255.0
    if dice:
        cup = tf.where(cup >= 0.5, 1.0, 0.0)
    
    return {'image' : image}, {'od' : od, 'cup' : cup}

def augment_images(image, od, cup, single_target = False):
    
    seeds = STATELESS_RNG.make_seeds(2)[0], STATELESS_RNG.make_seeds(2)[0]
    
    def augment(img, seeds):
        
        img = tf.image.stateless_random_flip_left_right(img, seeds[0])
        img = tf.image.stateless_random_flip_up_down(img, seeds[1])
        img = tf.image.resize_with_crop_or_pad(img, IMAGE_SIZE[0] + 20, IMAGE_SIZE[1] + 20)
        img = tf.image.stateless_random_crop(img, size = (*IMAGE_SIZE, img.shape[2]), seed = seeds[0])
        
        return img
    
    image = augment(image, seeds)
    od = augment(od, seeds)
    cup = augment(cup, seeds)
    
    if single_target:
        return image, od
    return {'image' : image}, {'od' : od, 'cup' : cup}

# %%
image, od, cup = load_image_and_gt(TRAIN_NORMAL_IMAGES[0])
plt.imshow(od)
image.shape
# Out:
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_042.png
# TensorShape([1750, 2050, 3])

# %%
rows = 6
cols = 5
fig, axes = plt.subplots(rows, cols, figsize = (15, 15))
axes = axes.flatten()

normal_images = np.random.choice(TRAIN_NORMAL_IMAGES, rows // 2)
glaucoma_images = np.random.choice(TRAIN_GLAUCOMA_IMAGES, rows - (rows // 2))

for idx, file in enumerate(normal_images):
    image, od, cup = load_image_and_gt(file)
    show_image_with_masks(image, od, cup, axes, index = idx, label = 'Normal :' + os.path.basename(file))
    
for idx, file in enumerate(glaucoma_images):
    image, od, cup = load_image_and_gt(file)
    show_image_with_masks(image, od, cup, axes, index = idx + rows // 2, label = 'Glaucoma :' + os.path.basename(file))

plt.tight_layout()
# Out:
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_017.png
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_035.png
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_089.png
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_038.png
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_012.png
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_088.png

# %%
def get_avgboundary(file):
    image = tf.io.read_file(file)
    image = tf.io.decode_png(image)
    
    cup_mask = np.zeros(shape = (image.shape[0], image.shape[1]))
    od_mask = np.zeros(shape = (image.shape[0], image.shape[1]))
    center_mask = np.zeros(shape = (image.shape[0], image.shape[1]))
    
    filename = Path(file).stem
    boundary_path = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'AvgBoundary')
    cup_file = os.path.join(boundary_path, filename + '_CupAvgBoundary.txt')
    od_file = os.path.join(boundary_path, filename + '_ODAvgBoundary.txt')
    center_file = os.path.join(boundary_path, filename + '_diskCenter.txt')
    
    count = 0
    with open(cup_file) as cf:
        for line in cf:
            a, b = line.split()
            a = int(a)
            b = int(b)
            cup_mask[a, b] = 255
            count += 1

    with open(od_file) as of:
        for line in of:
            a, b = line.split()
            a = int(a)
            b = int(b)
            od_mask[a, b] = 255
        
    with open(center_file) as ctrf:
        for line in ctrf:
            a, b = line.split()
            a = int(a)
            b = int(b)
            center_mask[a, b] = 255
    return od_mask.reshape(image.shape[0], image.shape[1], 1), \
cup_mask.reshape(image.shape[0], image.shape[1], 1), center_mask.reshape(image.shape[0], image.shape[1], 1)

# %%
glaucoma_avgboundary_test = TRAIN_GLAUCOMA_IMAGES[3]

od_mask, cup_mask, center_mask = get_avgboundary(glaucoma_avgboundary_test)
image, od, cup = load_image_and_gt(glaucoma_avgboundary_test)
# Out:
# ../input/drishtigs-retina-dataset-for-onh-segmentation/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_004.png

# %%
fig, axes = plt.subplots(2, 3, figsize = (20, 20))
axes = axes.flatten()

axes[0].imshow(image)
axes[0].set_title('Test Image')
axes[1].imshow(od)
axes[1].set_title('Optical Disk Mask')
axes[2].imshow(od_mask)
axes[2].set_title('Optical Disk Avg Boundary')
axes[3].imshow(cup)
axes[3].set_title('Cup Mask')
axes[4].imshow(cup_mask)
axes[4].set_title('Cup Avg Boundary')
axes[5].imshow(center_mask)
axes[5].set_title('Center Avg Boundary')
plt.tight_layout()

# %%
train_images = np.concatenate([TRAIN_NORMAL_IMAGES, TRAIN_GLAUCOMA_IMAGES])
test_images = np.concatenate([TEST_NORMAL_IMAGES, TEST_GLAUCOMA_IMAGES])

train_ds_dice = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = True), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup']))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

train_ds_no_dice = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = False), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup']))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

test_ds_dice = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = True, test = True), num_parallel_calls = AUTOTUNE)\
    .batch(batch_size = BATCH_SIZE)

test_ds_no_dice = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = False, test = True), num_parallel_calls = AUTOTUNE)\
    .batch(batch_size = BATCH_SIZE)

# %%
train_ds_no_dice_st = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = False), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup'], single_target = True))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

test_ds_no_dice_st = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = False, test = True), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: (image['image'], targets['od']))\
    .batch(batch_size = BATCH_SIZE)

# %%
def upsampling_block(inp, skips, filters, kernels, rates):
    '''
    Creates a block for upsampling
    Doubles the image dimensions
    And adds the skip connection
    '''   
    activation = 'relu'
    x = inp  
    for f, kernel, skip, rate in zip(filters, kernels, skips, rates):
        x = UpSampling2D()(x)
        x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
        x = concatenate([x, skip])
        x = BatchNormalization()(x)
        x = SpatialDropout2D(rate = rate)(x)
    return x

def conv_block(inp, filters, kernels, strides, rates):
    '''
    Builds a convulitional block
    When the strides reach 2
    Keeps the output of the last
    Conv layer to be used
    For a skip connection
    '''

    activation = 'relu'
    x = inp
    skips = []
    for f, kernel, stride, rate in zip(filters, kernels, strides, rates):
        if stride == 2:
            skips.append(skip)
            x = MaxPool2D()(x)
            x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
            skip = x
        else:
            x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
            skip = x
        
        x = BatchNormalization()(x)
        x = SpatialDropout2D(rate = rate)(x)
    
    return skips, x

# %%
def res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, up_filters, up_kernels, up_rates):
    '''
    Builds the u-net structure
    The output is two heads
    One for the Optical Disk
    And another for the cup
    '''
    inp = Input(shape = (*IMAGE_SIZE, 3), name = 'image')
    x = inp
    
    skips, x = conv_block(x, conv_filters, conv_kernels, conv_strides, conv_rates)
    
    skips = skips[::-1]
    
    od = upsampling_block(x, skips, up_filters, up_kernels, up_rates)
    od = Conv2D(filters = 1, kernel_size = 1, strides = 1, padding = 'same', activation = 'sigmoid', name = 'od')(od)
    
    cup = upsampling_block(x, skips, up_filters, up_kernels, up_rates)
    cup = Conv2D(filters = 1, kernel_size = 1, strides = 1, padding = 'same', activation = 'sigmoid', name = 'cup')(cup)
       
    return Model(inputs = inp, outputs = [od, cup])

# %%
def res_unet_st(conv_filters, conv_kernels, conv_strides, conv_rates, up_filters, up_kernels, up_rates):
    '''
    Builds the u-net structure
    The output is two heads
    One for the Optical Disk
    And another for the cup
    '''
    inp = Input(shape = (*IMAGE_SIZE, 3), name = 'image')
    x = inp
    
    skips, x = conv_block(x, conv_filters, conv_kernels, conv_strides, conv_rates)
    
    skips = skips[::-1]
    
    od = upsampling_block(x, skips, up_filters, up_kernels, up_rates)
    od = Conv2D(filters = 1, kernel_size = 1, strides = 1, padding = 'same', activation = 'sigmoid', name = 'od')(od)
           
    return Model(inputs = inp, outputs = od)

# %%
def dice(y, y_pred):
    '''
    Dice Loss, similar to
    Intersection over Union
    '''
    epsilon = EPSILON
    numerator = 2 * tf.reduce_sum(y * y_pred, axis = [1, 2])
    denominator = tf.reduce_sum(y + y_pred, axis = [1, 2])
    dice = tf.reduce_mean((numerator + epsilon)/(denominator + epsilon))
    return 1 - dice

# %%
conv_filters = [8, 16, 32, 64]
conv_kernels = [3, 3, 3, 3]
conv_strides = [1, 2, 2, 2]
conv_rates = [0.8, 0.8, 0.8, 0.8]

upsampling_filters = [32, 16, 8, 8]
upsampling_kernels = [3, 3, 3, 3]
upsampling_rates = [0.5, 0.5, 0.5, 0.5]

mod1 = res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, upsampling_filters, upsampling_kernels, upsampling_rates)
mod1.compile(optimizer = 'Adam', loss = {'od' : dice, 'cup' : dice}, metrics = ['accuracy'])

# %%
plot_model(mod1)

# %%
hist1 = mod1.fit(train_ds_dice, validation_data = test_ds_dice, callbacks = [early_stopping], epochs = 200)
# Out:
# Epoch 1/200
# 2023-09-15 14:50:26.650549: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2/2 [==============================] - 36s 11s/step - loss: 1.9009 - od_loss: 0.9312 - cup_loss: 0.9696 - od_accuracy: 0.5126 - cup_accuracy: 0.4873 - val_loss: 1.9057 - val_od_loss: 0.9394 - val_cup_loss: 0.9663 - val_od_accuracy: 0.6801 - val_cup_accuracy: 0.9816
# Epoch 2/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8858 - od_loss: 0.9189 - cup_loss: 0.9668 - od_accuracy: 0.5823 - cup_accuracy: 0.5583 - val_loss: 1.9052 - val_od_loss: 0.9390 - val_cup_loss: 0.9663 - val_od_accuracy: 0.9223 - val_cup_accuracy: 0.9827
# Epoch 3/200
# 2/2 [==============================] - 5s 4s/step - loss: 1.8900 - od_loss: 0.9233 - cup_loss: 0.9666 - od_accuracy: 0.5531 - cup_accuracy: 0.5522 - val_loss: 1.9047 - val_od_loss: 0.9385 - val_cup_loss: 0.9662 - val_od_accuracy: 0.9630 - val_cup_accuracy: 0.9827
# Epoch 4/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8845 - od_loss: 0.9185 - cup_loss: 0.9660 - od_accuracy: 0.5826 - cup_accuracy: 0.5711 - val_loss: 1.9041 - val_od_loss: 0.9380 - val_cup_loss: 0.9661 - val_od_accuracy: 0.9748 - val_cup_accuracy: 0.9824
# Epoch 5/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8793 - od_loss: 0.9143 - cup_loss: 0.9650 - od_accuracy: 0.5806 - cup_accuracy: 0.6358 - val_loss: 1.9036 - val_od_loss: 0.9375 - val_cup_loss: 0.9661 - val_od_accuracy: 0.9772 - val_cup_accuracy: 0.9824
# Epoch 6/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8834 - od_loss: 0.9189 - cup_loss: 0.9645 - od_accuracy: 0.5762 - cup_accuracy: 0.6355 - val_loss: 1.9031 - val_od_loss: 0.9371 - val_cup_loss: 0.9660 - val_od_accuracy: 0.9766 - val_cup_accuracy: 0.9825
# Epoch 7/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8730 - od_loss: 0.9100 - cup_loss: 0.9629 - od_accuracy: 0.6448 - cup_accuracy: 0.6783 - val_loss: 1.9026 - val_od_loss: 0.9366 - val_cup_loss: 0.9660 - val_od_accuracy: 0.9749 - val_cup_accuracy: 0.9825
# Epoch 8/200
# 2/2 [==============================] - 5s 4s/step - loss: 1.8768 - od_loss: 0.9126 - cup_loss: 0.9642 - od_accuracy: 0.6373 - cup_accuracy: 0.5729 - val_loss: 1.9021 - val_od_loss: 0.9362 - val_cup_loss: 0.9659 - val_od_accuracy: 0.9737 - val_cup_accuracy: 0.9825
# Epoch 9/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8812 - od_loss: 0.9167 - cup_loss: 0.9645 - od_accuracy: 0.5675 - cup_accuracy: 0.6278 - val_loss: 1.9017 - val_od_loss: 0.9358 - val_cup_loss: 0.9658 - val_od_accuracy: 0.9726 - val_cup_accuracy: 0.9825
# Epoch 10/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8709 - od_loss: 0.9082 - cup_loss: 0.9627 - od_accuracy: 0.6069 - cup_accuracy: 0.6698 - val_loss: 1.9012 - val_od_loss: 0.9354 - val_cup_loss: 0.9658 - val_od_accuracy: 0.9713 - val_cup_accuracy: 0.9825
# Epoch 11/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8625 - od_loss: 0.9022 - cup_loss: 0.9602 - od_accuracy: 0.6654 - cup_accuracy: 0.6112 - val_loss: 1.9007 - val_od_loss: 0.9350 - val_cup_loss: 0.9657 - val_od_accuracy: 0.9704 - val_cup_accuracy: 0.9825
# Epoch 12/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8602 - od_loss: 0.8970 - cup_loss: 0.9632 - od_accuracy: 0.6725 - cup_accuracy: 0.7179 - val_loss: 1.9002 - val_od_loss: 0.9345 - val_cup_loss: 0.9656 - val_od_accuracy: 0.9699 - val_cup_accuracy: 0.9825
# Epoch 13/200
# 2/2 [==============================] - 5s 4s/step - loss: 1.8641 - od_loss: 0.9078 - cup_loss: 0.9563 - od_accuracy: 0.7006 - cup_accuracy: 0.7290 - val_loss: 1.8997 - val_od_loss: 0.9342 - val_cup_loss: 0.9655 - val_od_accuracy: 0.9694 - val_cup_accuracy: 0.9825
# Epoch 14/200
# 2/2 [==============================] - 5s 5s/step - loss: 1.8616 - od_loss: 0.9015 - cup_loss: 0.9601 - od_accuracy: 0.7091 - cup_accuracy: 0.7102 - val_loss: 1.8993 - val_od_loss: 0.9339 - val_cup_loss: 0.9654 - val_od_accuracy: 0.9692 - val_cup_accuracy: 0.9825
# Epoch 15/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8401 - od_loss: 0.8857 - cup_loss: 0.9544 - od_accuracy: 0.6526 - cup_accuracy: 0.6791 - val_loss: 1.8987 - val_od_loss: 0.9335 - val_cup_loss: 0.9652 - val_od_accuracy: 0.9689 - val_cup_accuracy: 0.9825
# Epoch 16/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8526 - od_loss: 0.8938 - cup_loss: 0.9587 - od_accuracy: 0.6558 - cup_accuracy: 0.6707 - val_loss: 1.8983 - val_od_loss: 0.9332 - val_cup_loss: 0.9651 - val_od_accuracy: 0.9687 - val_cup_accuracy: 0.9825
# Epoch 17/200
# 2/2 [==============================] - 5s 4s/step - loss: 1.8669 - od_loss: 0.9064 - cup_loss: 0.9605 - od_accuracy: 0.6347 - cup_accuracy: 0.6773 - val_loss: 1.8978 - val_od_loss: 0.9329 - val_cup_loss: 0.9649 - val_od_accuracy: 0.9686 - val_cup_accuracy: 0.9825
# Epoch 18/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8655 - od_loss: 0.9049 - cup_loss: 0.9605 - od_accuracy: 0.6735 - cup_accuracy: 0.7171 - val_loss: 1.8973 - val_od_loss: 0.9326 - val_cup_loss: 0.9646 - val_od_accuracy: 0.9686 - val_cup_accuracy: 0.9825
# Epoch 19/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8699 - od_loss: 0.9111 - cup_loss: 0.9588 - od_accuracy: 0.7048 - cup_accuracy: 0.7465 - val_loss: 1.8969 - val_od_loss: 0.9323 - val_cup_loss: 0.9645 - val_od_accuracy: 0.9685 - val_cup_accuracy: 0.9825
# Epoch 20/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8403 - od_loss: 0.8843 - cup_loss: 0.9561 - od_accuracy: 0.7036 - cup_accuracy: 0.7069 - val_loss: 1.8966 - val_od_loss: 0.9322 - val_cup_loss: 0.9644 - val_od_accuracy: 0.9684 - val_cup_accuracy: 0.9825
# Epoch 21/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8596 - od_loss: 0.9061 - cup_loss: 0.9535 - od_accuracy: 0.6267 - cup_accuracy: 0.7019 - val_loss: 1.8963 - val_od_loss: 0.9319 - val_cup_loss: 0.9644 - val_od_accuracy: 0.9684 - val_cup_accuracy: 0.9825
# Epoch 22/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8294 - od_loss: 0.8800 - cup_loss: 0.9493 - od_accuracy: 0.6656 - cup_accuracy: 0.7510 - val_loss: 1.8961 - val_od_loss: 0.9317 - val_cup_loss: 0.9644 - val_od_accuracy: 0.9684 - val_cup_accuracy: 0.9825
# Epoch 23/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8471 - od_loss: 0.8905 - cup_loss: 0.9567 - od_accuracy: 0.6959 - cup_accuracy: 0.7275 - val_loss: 1.8960 - val_od_loss: 0.9316 - val_cup_loss: 0.9643 - val_od_accuracy: 0.9684 - val_cup_accuracy: 0.9825
# Epoch 24/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8590 - od_loss: 0.9005 - cup_loss: 0.9586 - od_accuracy: 0.6649 - cup_accuracy: 0.7208 - val_loss: 1.8957 - val_od_loss: 0.9315 - val_cup_loss: 0.9643 - val_od_accuracy: 0.9684 - val_cup_accuracy: 0.9825
# Epoch 25/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8483 - od_loss: 0.8891 - cup_loss: 0.9591 - od_accuracy: 0.7012 - cup_accuracy: 0.7059 - val_loss: 1.8956 - val_od_loss: 0.9314 - val_cup_loss: 0.9642 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 26/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8072 - od_loss: 0.8552 - cup_loss: 0.9521 - od_accuracy: 0.6355 - cup_accuracy: 0.7303 - val_loss: 1.8955 - val_od_loss: 0.9314 - val_cup_loss: 0.9641 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 27/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8197 - od_loss: 0.8690 - cup_loss: 0.9507 - od_accuracy: 0.7086 - cup_accuracy: 0.6666 - val_loss: 1.8955 - val_od_loss: 0.9314 - val_cup_loss: 0.9641 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 28/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8062 - od_loss: 0.8595 - cup_loss: 0.9466 - od_accuracy: 0.6838 - cup_accuracy: 0.7126 - val_loss: 1.8953 - val_od_loss: 0.9313 - val_cup_loss: 0.9640 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 29/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8058 - od_loss: 0.8636 - cup_loss: 0.9422 - od_accuracy: 0.7087 - cup_accuracy: 0.6825 - val_loss: 1.8953 - val_od_loss: 0.9314 - val_cup_loss: 0.9639 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 30/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8549 - od_loss: 0.9004 - cup_loss: 0.9545 - od_accuracy: 0.6852 - cup_accuracy: 0.7171 - val_loss: 1.8955 - val_od_loss: 0.9316 - val_cup_loss: 0.9639 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 31/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8122 - od_loss: 0.8678 - cup_loss: 0.9445 - od_accuracy: 0.6870 - cup_accuracy: 0.7826 - val_loss: 1.8957 - val_od_loss: 0.9319 - val_cup_loss: 0.9638 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 32/200
# 2/2 [==============================] - 4s 4s/step - loss: 1.8196 - od_loss: 0.8755 - cup_loss: 0.9441 - od_accuracy: 0.6689 - cup_accuracy: 0.7313 - val_loss: 1.8959 - val_od_loss: 0.9322 - val_cup_loss: 0.9637 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825
# Epoch 33/200
# 2/2 [==============================] - 6s 5s/step - loss: 1.8271 - od_loss: 0.8816 - cup_loss: 0.9455 - od_accuracy: 0.6733 - cup_accuracy: 0.6685 - val_loss: 1.8967 - val_od_loss: 0.9330 - val_cup_loss: 0.9637 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9825

# %%
mod2 = res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, upsampling_filters, upsampling_kernels, upsampling_rates)
mod2.compile(optimizer = 'Adam', loss = {'od' : 'binary_crossentropy', 'cup' : 'binary_crossentropy'}, metrics = ['accuracy'])
hist2 = mod2.fit(train_ds_no_dice, validation_data = test_ds_no_dice, callbacks = [early_stopping], epochs = 100)
# Out:
# Epoch 1/100
# 2023-09-15 14:54:03.235686: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/spatial_dropout2d_10/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2/2 [==============================] - 17s 5s/step - loss: 1.7801 - od_loss: 0.9348 - cup_loss: 0.8453 - od_accuracy: 0.4559 - cup_accuracy: 0.4965 - val_loss: 1.4888 - val_od_loss: 0.7522 - val_cup_loss: 0.7366 - val_od_accuracy: 0.1584 - val_cup_accuracy: 0.1467
# Epoch 2/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.9160 - od_loss: 0.9965 - cup_loss: 0.9195 - od_accuracy: 0.5045 - cup_accuracy: 0.4794 - val_loss: 1.4933 - val_od_loss: 0.7628 - val_cup_loss: 0.7304 - val_od_accuracy: 0.1748 - val_cup_accuracy: 0.1588
# Epoch 3/100
# 2/2 [==============================] - 5s 5s/step - loss: 1.9865 - od_loss: 1.0311 - cup_loss: 0.9554 - od_accuracy: 0.4545 - cup_accuracy: 0.4687 - val_loss: 1.4913 - val_od_loss: 0.7639 - val_cup_loss: 0.7274 - val_od_accuracy: 0.1792 - val_cup_accuracy: 0.1645
# Epoch 4/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.9106 - od_loss: 0.9675 - cup_loss: 0.9431 - od_accuracy: 0.4649 - cup_accuracy: 0.4545 - val_loss: 1.4834 - val_od_loss: 0.7576 - val_cup_loss: 0.7258 - val_od_accuracy: 0.1885 - val_cup_accuracy: 0.1722
# Epoch 5/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.8750 - od_loss: 1.0299 - cup_loss: 0.8451 - od_accuracy: 0.5192 - cup_accuracy: 0.5211 - val_loss: 1.4697 - val_od_loss: 0.7481 - val_cup_loss: 0.7216 - val_od_accuracy: 0.2026 - val_cup_accuracy: 0.1896
# Epoch 6/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.7078 - od_loss: 0.8561 - cup_loss: 0.8516 - od_accuracy: 0.5312 - cup_accuracy: 0.4432 - val_loss: 1.4510 - val_od_loss: 0.7373 - val_cup_loss: 0.7137 - val_od_accuracy: 0.2202 - val_cup_accuracy: 0.2267
# Epoch 7/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.6983 - od_loss: 0.8612 - cup_loss: 0.8371 - od_accuracy: 0.4941 - cup_accuracy: 0.4951 - val_loss: 1.4319 - val_od_loss: 0.7272 - val_cup_loss: 0.7047 - val_od_accuracy: 0.2411 - val_cup_accuracy: 0.2938
# Epoch 8/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.6964 - od_loss: 0.8744 - cup_loss: 0.8220 - od_accuracy: 0.5329 - cup_accuracy: 0.4694 - val_loss: 1.4150 - val_od_loss: 0.7176 - val_cup_loss: 0.6974 - val_od_accuracy: 0.2691 - val_cup_accuracy: 0.3616
# Epoch 9/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.6362 - od_loss: 0.8461 - cup_loss: 0.7900 - od_accuracy: 0.5223 - cup_accuracy: 0.5283 - val_loss: 1.3949 - val_od_loss: 0.7072 - val_cup_loss: 0.6878 - val_od_accuracy: 0.3183 - val_cup_accuracy: 0.4887
# Epoch 10/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.5825 - od_loss: 0.8098 - cup_loss: 0.7727 - od_accuracy: 0.5525 - cup_accuracy: 0.5144 - val_loss: 1.3758 - val_od_loss: 0.6966 - val_cup_loss: 0.6793 - val_od_accuracy: 0.3964 - val_cup_accuracy: 0.6184
# Epoch 11/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.6915 - od_loss: 0.8463 - cup_loss: 0.8452 - od_accuracy: 0.4880 - cup_accuracy: 0.4733 - val_loss: 1.3570 - val_od_loss: 0.6868 - val_cup_loss: 0.6702 - val_od_accuracy: 0.5025 - val_cup_accuracy: 0.7678
# Epoch 12/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.6123 - od_loss: 0.8071 - cup_loss: 0.8052 - od_accuracy: 0.5376 - cup_accuracy: 0.4737 - val_loss: 1.3378 - val_od_loss: 0.6772 - val_cup_loss: 0.6606 - val_od_accuracy: 0.6273 - val_cup_accuracy: 0.8921
# Epoch 13/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.5038 - od_loss: 0.7683 - cup_loss: 0.7355 - od_accuracy: 0.5709 - cup_accuracy: 0.5821 - val_loss: 1.3205 - val_od_loss: 0.6689 - val_cup_loss: 0.6516 - val_od_accuracy: 0.7403 - val_cup_accuracy: 0.9511
# Epoch 14/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.5507 - od_loss: 0.8040 - cup_loss: 0.7466 - od_accuracy: 0.5653 - cup_accuracy: 0.5194 - val_loss: 1.3033 - val_od_loss: 0.6608 - val_cup_loss: 0.6425 - val_od_accuracy: 0.8417 - val_cup_accuracy: 0.9766
# Epoch 15/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.4975 - od_loss: 0.7453 - cup_loss: 0.7522 - od_accuracy: 0.5570 - cup_accuracy: 0.5409 - val_loss: 1.2872 - val_od_loss: 0.6535 - val_cup_loss: 0.6337 - val_od_accuracy: 0.9076 - val_cup_accuracy: 0.9829
# Epoch 16/100
# 2/2 [==============================] - 6s 6s/step - loss: 1.4072 - od_loss: 0.6882 - cup_loss: 0.7190 - od_accuracy: 0.6042 - cup_accuracy: 0.5787 - val_loss: 1.2722 - val_od_loss: 0.6464 - val_cup_loss: 0.6258 - val_od_accuracy: 0.9429 - val_cup_accuracy: 0.9826
# Epoch 17/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.5012 - od_loss: 0.7681 - cup_loss: 0.7331 - od_accuracy: 0.5401 - cup_accuracy: 0.5860 - val_loss: 1.2558 - val_od_loss: 0.6396 - val_cup_loss: 0.6162 - val_od_accuracy: 0.9591 - val_cup_accuracy: 0.9817
# Epoch 18/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.4339 - od_loss: 0.6698 - cup_loss: 0.7642 - od_accuracy: 0.6295 - cup_accuracy: 0.5221 - val_loss: 1.2399 - val_od_loss: 0.6332 - val_cup_loss: 0.6067 - val_od_accuracy: 0.9673 - val_cup_accuracy: 0.9810
# Epoch 19/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.4147 - od_loss: 0.7207 - cup_loss: 0.6940 - od_accuracy: 0.6085 - cup_accuracy: 0.6113 - val_loss: 1.2250 - val_od_loss: 0.6266 - val_cup_loss: 0.5984 - val_od_accuracy: 0.9723 - val_cup_accuracy: 0.9803
# Epoch 20/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.4265 - od_loss: 0.7210 - cup_loss: 0.7054 - od_accuracy: 0.5806 - cup_accuracy: 0.6265 - val_loss: 1.2087 - val_od_loss: 0.6198 - val_cup_loss: 0.5890 - val_od_accuracy: 0.9743 - val_cup_accuracy: 0.9797
# Epoch 21/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.4221 - od_loss: 0.7239 - cup_loss: 0.6982 - od_accuracy: 0.5824 - cup_accuracy: 0.6041 - val_loss: 1.1951 - val_od_loss: 0.6144 - val_cup_loss: 0.5807 - val_od_accuracy: 0.9745 - val_cup_accuracy: 0.9794
# Epoch 22/100
# 2/2 [==============================] - 5s 5s/step - loss: 1.3857 - od_loss: 0.6946 - cup_loss: 0.6911 - od_accuracy: 0.6086 - cup_accuracy: 0.5995 - val_loss: 1.1822 - val_od_loss: 0.6094 - val_cup_loss: 0.5728 - val_od_accuracy: 0.9735 - val_cup_accuracy: 0.9793
# Epoch 23/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.4478 - od_loss: 0.7579 - cup_loss: 0.6899 - od_accuracy: 0.5895 - cup_accuracy: 0.6323 - val_loss: 1.1691 - val_od_loss: 0.6043 - val_cup_loss: 0.5648 - val_od_accuracy: 0.9719 - val_cup_accuracy: 0.9791
# Epoch 24/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.3106 - od_loss: 0.6930 - cup_loss: 0.6176 - od_accuracy: 0.6407 - cup_accuracy: 0.7153 - val_loss: 1.1565 - val_od_loss: 0.5987 - val_cup_loss: 0.5578 - val_od_accuracy: 0.9703 - val_cup_accuracy: 0.9790
# Epoch 25/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.3671 - od_loss: 0.7077 - cup_loss: 0.6594 - od_accuracy: 0.6129 - cup_accuracy: 0.6661 - val_loss: 1.1458 - val_od_loss: 0.5932 - val_cup_loss: 0.5525 - val_od_accuracy: 0.9691 - val_cup_accuracy: 0.9790
# Epoch 26/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.2809 - od_loss: 0.6586 - cup_loss: 0.6223 - od_accuracy: 0.6625 - cup_accuracy: 0.6459 - val_loss: 1.1372 - val_od_loss: 0.5883 - val_cup_loss: 0.5489 - val_od_accuracy: 0.9682 - val_cup_accuracy: 0.9790
# Epoch 27/100
# 2/2 [==============================] - 5s 4s/step - loss: 1.2295 - od_loss: 0.5838 - cup_loss: 0.6457 - od_accuracy: 0.7562 - cup_accuracy: 0.6488 - val_loss: 1.1274 - val_od_loss: 0.5832 - val_cup_loss: 0.5442 - val_od_accuracy: 0.9676 - val_cup_accuracy: 0.9790
# Epoch 28/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.4208 - od_loss: 0.7337 - cup_loss: 0.6871 - od_accuracy: 0.6665 - cup_accuracy: 0.6297 - val_loss: 1.1162 - val_od_loss: 0.5780 - val_cup_loss: 0.5382 - val_od_accuracy: 0.9670 - val_cup_accuracy: 0.9790
# Epoch 29/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.3099 - od_loss: 0.6585 - cup_loss: 0.6514 - od_accuracy: 0.6369 - cup_accuracy: 0.6392 - val_loss: 1.1048 - val_od_loss: 0.5724 - val_cup_loss: 0.5324 - val_od_accuracy: 0.9665 - val_cup_accuracy: 0.9790
# Epoch 30/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.3072 - od_loss: 0.6691 - cup_loss: 0.6381 - od_accuracy: 0.7068 - cup_accuracy: 0.6619 - val_loss: 1.0943 - val_od_loss: 0.5669 - val_cup_loss: 0.5274 - val_od_accuracy: 0.9664 - val_cup_accuracy: 0.9790
# Epoch 31/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.3033 - od_loss: 0.6246 - cup_loss: 0.6787 - od_accuracy: 0.7018 - cup_accuracy: 0.6578 - val_loss: 1.0852 - val_od_loss: 0.5613 - val_cup_loss: 0.5240 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 32/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.2700 - od_loss: 0.6461 - cup_loss: 0.6239 - od_accuracy: 0.7025 - cup_accuracy: 0.7016 - val_loss: 1.0758 - val_od_loss: 0.5557 - val_cup_loss: 0.5201 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 33/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.2446 - od_loss: 0.6341 - cup_loss: 0.6105 - od_accuracy: 0.7145 - cup_accuracy: 0.7466 - val_loss: 1.0671 - val_od_loss: 0.5499 - val_cup_loss: 0.5172 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 34/100
# 2/2 [==============================] - 5s 5s/step - loss: 1.2204 - od_loss: 0.5815 - cup_loss: 0.6389 - od_accuracy: 0.7741 - cup_accuracy: 0.7163 - val_loss: 1.0602 - val_od_loss: 0.5448 - val_cup_loss: 0.5154 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 35/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.2033 - od_loss: 0.5864 - cup_loss: 0.6169 - od_accuracy: 0.7596 - cup_accuracy: 0.7166 - val_loss: 1.0555 - val_od_loss: 0.5410 - val_cup_loss: 0.5145 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 36/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.2633 - od_loss: 0.6087 - cup_loss: 0.6546 - od_accuracy: 0.7644 - cup_accuracy: 0.7036 - val_loss: 1.0525 - val_od_loss: 0.5377 - val_cup_loss: 0.5148 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 37/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.1662 - od_loss: 0.5742 - cup_loss: 0.5920 - od_accuracy: 0.7692 - cup_accuracy: 0.7430 - val_loss: 1.0477 - val_od_loss: 0.5342 - val_cup_loss: 0.5135 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 38/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.2558 - od_loss: 0.5997 - cup_loss: 0.6561 - od_accuracy: 0.7478 - cup_accuracy: 0.6773 - val_loss: 1.0433 - val_od_loss: 0.5303 - val_cup_loss: 0.5130 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 39/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.2505 - od_loss: 0.6081 - cup_loss: 0.6424 - od_accuracy: 0.7230 - cup_accuracy: 0.6871 - val_loss: 1.0405 - val_od_loss: 0.5260 - val_cup_loss: 0.5145 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 40/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.2283 - od_loss: 0.6320 - cup_loss: 0.5964 - od_accuracy: 0.7584 - cup_accuracy: 0.7074 - val_loss: 1.0372 - val_od_loss: 0.5227 - val_cup_loss: 0.5145 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 41/100
# 2/2 [==============================] - 5s 5s/step - loss: 1.2682 - od_loss: 0.5926 - cup_loss: 0.6756 - od_accuracy: 0.7821 - cup_accuracy: 0.6701 - val_loss: 1.0359 - val_od_loss: 0.5199 - val_cup_loss: 0.5160 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 42/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1794 - od_loss: 0.5985 - cup_loss: 0.5808 - od_accuracy: 0.7695 - cup_accuracy: 0.7338 - val_loss: 1.0333 - val_od_loss: 0.5165 - val_cup_loss: 0.5168 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 43/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1691 - od_loss: 0.5610 - cup_loss: 0.6080 - od_accuracy: 0.7918 - cup_accuracy: 0.7570 - val_loss: 1.0306 - val_od_loss: 0.5133 - val_cup_loss: 0.5173 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 44/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1985 - od_loss: 0.5695 - cup_loss: 0.6289 - od_accuracy: 0.7863 - cup_accuracy: 0.7267 - val_loss: 1.0274 - val_od_loss: 0.5095 - val_cup_loss: 0.5179 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 45/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1163 - od_loss: 0.5206 - cup_loss: 0.5956 - od_accuracy: 0.8204 - cup_accuracy: 0.7656 - val_loss: 1.0237 - val_od_loss: 0.5054 - val_cup_loss: 0.5183 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 46/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1888 - od_loss: 0.6228 - cup_loss: 0.5660 - od_accuracy: 0.7614 - cup_accuracy: 0.8068 - val_loss: 1.0180 - val_od_loss: 0.5010 - val_cup_loss: 0.5170 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 47/100
# 2/2 [==============================] - 5s 4s/step - loss: 1.1129 - od_loss: 0.5284 - cup_loss: 0.5845 - od_accuracy: 0.8256 - cup_accuracy: 0.7723 - val_loss: 1.0124 - val_od_loss: 0.4972 - val_cup_loss: 0.5152 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 48/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1715 - od_loss: 0.5990 - cup_loss: 0.5725 - od_accuracy: 0.7966 - cup_accuracy: 0.7643 - val_loss: 1.0066 - val_od_loss: 0.4933 - val_cup_loss: 0.5134 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 49/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.1084 - od_loss: 0.5455 - cup_loss: 0.5629 - od_accuracy: 0.7995 - cup_accuracy: 0.8061 - val_loss: 1.0009 - val_od_loss: 0.4893 - val_cup_loss: 0.5115 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 50/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.1474 - od_loss: 0.5521 - cup_loss: 0.5952 - od_accuracy: 0.7907 - cup_accuracy: 0.7808 - val_loss: 0.9958 - val_od_loss: 0.4856 - val_cup_loss: 0.5102 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 51/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.1601 - od_loss: 0.5718 - cup_loss: 0.5883 - od_accuracy: 0.7812 - cup_accuracy: 0.7238 - val_loss: 0.9902 - val_od_loss: 0.4818 - val_cup_loss: 0.5084 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 52/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.0815 - od_loss: 0.5190 - cup_loss: 0.5624 - od_accuracy: 0.8510 - cup_accuracy: 0.8244 - val_loss: 0.9841 - val_od_loss: 0.4792 - val_cup_loss: 0.5049 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 53/100
# 2/2 [==============================] - 5s 5s/step - loss: 1.1006 - od_loss: 0.5667 - cup_loss: 0.5339 - od_accuracy: 0.7768 - cup_accuracy: 0.8364 - val_loss: 0.9786 - val_od_loss: 0.4775 - val_cup_loss: 0.5011 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 54/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.0856 - od_loss: 0.5416 - cup_loss: 0.5441 - od_accuracy: 0.8404 - cup_accuracy: 0.8398 - val_loss: 0.9715 - val_od_loss: 0.4749 - val_cup_loss: 0.4966 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 55/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.1324 - od_loss: 0.5405 - cup_loss: 0.5919 - od_accuracy: 0.8594 - cup_accuracy: 0.7881 - val_loss: 0.9653 - val_od_loss: 0.4730 - val_cup_loss: 0.4923 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 56/100
# 2/2 [==============================] - 6s 5s/step - loss: 1.1018 - od_loss: 0.5517 - cup_loss: 0.5501 - od_accuracy: 0.8845 - cup_accuracy: 0.8458 - val_loss: 0.9594 - val_od_loss: 0.4718 - val_cup_loss: 0.4876 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 57/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9876 - od_loss: 0.4815 - cup_loss: 0.5061 - od_accuracy: 0.9027 - cup_accuracy: 0.8881 - val_loss: 0.9530 - val_od_loss: 0.4692 - val_cup_loss: 0.4838 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 58/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.0107 - od_loss: 0.5142 - cup_loss: 0.4965 - od_accuracy: 0.8765 - cup_accuracy: 0.9102 - val_loss: 0.9462 - val_od_loss: 0.4661 - val_cup_loss: 0.4801 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 59/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9618 - od_loss: 0.4639 - cup_loss: 0.4979 - od_accuracy: 0.9161 - cup_accuracy: 0.8882 - val_loss: 0.9402 - val_od_loss: 0.4630 - val_cup_loss: 0.4772 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 60/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9533 - od_loss: 0.4733 - cup_loss: 0.4800 - od_accuracy: 0.8895 - cup_accuracy: 0.9162 - val_loss: 0.9331 - val_od_loss: 0.4593 - val_cup_loss: 0.4738 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 61/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.0484 - od_loss: 0.4906 - cup_loss: 0.5578 - od_accuracy: 0.8996 - cup_accuracy: 0.8610 - val_loss: 0.9264 - val_od_loss: 0.4552 - val_cup_loss: 0.4712 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 62/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9869 - od_loss: 0.4838 - cup_loss: 0.5030 - od_accuracy: 0.8761 - cup_accuracy: 0.8717 - val_loss: 0.9181 - val_od_loss: 0.4506 - val_cup_loss: 0.4675 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 63/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9979 - od_loss: 0.4699 - cup_loss: 0.5280 - od_accuracy: 0.8521 - cup_accuracy: 0.8621 - val_loss: 0.9101 - val_od_loss: 0.4460 - val_cup_loss: 0.4641 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 64/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.0152 - od_loss: 0.5058 - cup_loss: 0.5094 - od_accuracy: 0.8406 - cup_accuracy: 0.8758 - val_loss: 0.9027 - val_od_loss: 0.4413 - val_cup_loss: 0.4614 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 65/100
# 2/2 [==============================] - 4s 4s/step - loss: 1.0102 - od_loss: 0.5297 - cup_loss: 0.4805 - od_accuracy: 0.8687 - cup_accuracy: 0.9198 - val_loss: 0.8966 - val_od_loss: 0.4372 - val_cup_loss: 0.4594 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 66/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9726 - od_loss: 0.4635 - cup_loss: 0.5091 - od_accuracy: 0.9028 - cup_accuracy: 0.8890 - val_loss: 0.8920 - val_od_loss: 0.4328 - val_cup_loss: 0.4592 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 67/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9374 - od_loss: 0.4601 - cup_loss: 0.4773 - od_accuracy: 0.9032 - cup_accuracy: 0.8968 - val_loss: 0.8859 - val_od_loss: 0.4280 - val_cup_loss: 0.4579 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 68/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9443 - od_loss: 0.4665 - cup_loss: 0.4777 - od_accuracy: 0.9047 - cup_accuracy: 0.9248 - val_loss: 0.8796 - val_od_loss: 0.4234 - val_cup_loss: 0.4562 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 69/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9526 - od_loss: 0.4544 - cup_loss: 0.4982 - od_accuracy: 0.9174 - cup_accuracy: 0.8939 - val_loss: 0.8738 - val_od_loss: 0.4186 - val_cup_loss: 0.4552 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 70/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9096 - od_loss: 0.4509 - cup_loss: 0.4587 - od_accuracy: 0.9201 - cup_accuracy: 0.9312 - val_loss: 0.8693 - val_od_loss: 0.4143 - val_cup_loss: 0.4551 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 71/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9691 - od_loss: 0.4917 - cup_loss: 0.4774 - od_accuracy: 0.9300 - cup_accuracy: 0.9481 - val_loss: 0.8646 - val_od_loss: 0.4106 - val_cup_loss: 0.4541 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 72/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9857 - od_loss: 0.5007 - cup_loss: 0.4850 - od_accuracy: 0.9059 - cup_accuracy: 0.9253 - val_loss: 0.8605 - val_od_loss: 0.4074 - val_cup_loss: 0.4532 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 73/100
# 2/2 [==============================] - 6s 6s/step - loss: 0.9233 - od_loss: 0.4536 - cup_loss: 0.4697 - od_accuracy: 0.9089 - cup_accuracy: 0.9324 - val_loss: 0.8561 - val_od_loss: 0.4038 - val_cup_loss: 0.4523 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 74/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.9346 - od_loss: 0.4491 - cup_loss: 0.4855 - od_accuracy: 0.9180 - cup_accuracy: 0.9441 - val_loss: 0.8524 - val_od_loss: 0.4006 - val_cup_loss: 0.4517 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 75/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.9160 - od_loss: 0.4433 - cup_loss: 0.4727 - od_accuracy: 0.9534 - cup_accuracy: 0.9557 - val_loss: 0.8486 - val_od_loss: 0.3979 - val_cup_loss: 0.4507 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 76/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8808 - od_loss: 0.4351 - cup_loss: 0.4457 - od_accuracy: 0.9480 - cup_accuracy: 0.9558 - val_loss: 0.8441 - val_od_loss: 0.3949 - val_cup_loss: 0.4492 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 77/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8674 - od_loss: 0.4173 - cup_loss: 0.4501 - od_accuracy: 0.9431 - cup_accuracy: 0.9545 - val_loss: 0.8384 - val_od_loss: 0.3916 - val_cup_loss: 0.4468 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 78/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8696 - od_loss: 0.4259 - cup_loss: 0.4436 - od_accuracy: 0.9475 - cup_accuracy: 0.9529 - val_loss: 0.8316 - val_od_loss: 0.3879 - val_cup_loss: 0.4437 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 79/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8715 - od_loss: 0.4233 - cup_loss: 0.4482 - od_accuracy: 0.9279 - cup_accuracy: 0.9406 - val_loss: 0.8251 - val_od_loss: 0.3846 - val_cup_loss: 0.4405 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 80/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8576 - od_loss: 0.4143 - cup_loss: 0.4432 - od_accuracy: 0.9457 - cup_accuracy: 0.9590 - val_loss: 0.8188 - val_od_loss: 0.3812 - val_cup_loss: 0.4376 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 81/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8199 - od_loss: 0.4056 - cup_loss: 0.4143 - od_accuracy: 0.9315 - cup_accuracy: 0.9641 - val_loss: 0.8118 - val_od_loss: 0.3777 - val_cup_loss: 0.4341 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 82/100
# 2/2 [==============================] - 5s 4s/step - loss: 0.9200 - od_loss: 0.4509 - cup_loss: 0.4691 - od_accuracy: 0.9222 - cup_accuracy: 0.9459 - val_loss: 0.8045 - val_od_loss: 0.3744 - val_cup_loss: 0.4301 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 83/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8447 - od_loss: 0.4393 - cup_loss: 0.4054 - od_accuracy: 0.9242 - cup_accuracy: 0.9699 - val_loss: 0.7981 - val_od_loss: 0.3722 - val_cup_loss: 0.4259 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 84/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8531 - od_loss: 0.4193 - cup_loss: 0.4338 - od_accuracy: 0.9539 - cup_accuracy: 0.9633 - val_loss: 0.7920 - val_od_loss: 0.3705 - val_cup_loss: 0.4215 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 85/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8280 - od_loss: 0.4150 - cup_loss: 0.4130 - od_accuracy: 0.9489 - cup_accuracy: 0.9638 - val_loss: 0.7860 - val_od_loss: 0.3688 - val_cup_loss: 0.4173 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 86/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8358 - od_loss: 0.4278 - cup_loss: 0.4080 - od_accuracy: 0.9493 - cup_accuracy: 0.9662 - val_loss: 0.7802 - val_od_loss: 0.3670 - val_cup_loss: 0.4132 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 87/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8334 - od_loss: 0.4256 - cup_loss: 0.4078 - od_accuracy: 0.9497 - cup_accuracy: 0.9656 - val_loss: 0.7739 - val_od_loss: 0.3648 - val_cup_loss: 0.4091 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 88/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7904 - od_loss: 0.3920 - cup_loss: 0.3983 - od_accuracy: 0.9591 - cup_accuracy: 0.9723 - val_loss: 0.7672 - val_od_loss: 0.3621 - val_cup_loss: 0.4050 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 89/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.8213 - od_loss: 0.4054 - cup_loss: 0.4158 - od_accuracy: 0.9546 - cup_accuracy: 0.9626 - val_loss: 0.7608 - val_od_loss: 0.3593 - val_cup_loss: 0.4015 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 90/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7740 - od_loss: 0.3868 - cup_loss: 0.3872 - od_accuracy: 0.9553 - cup_accuracy: 0.9697 - val_loss: 0.7537 - val_od_loss: 0.3561 - val_cup_loss: 0.3976 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 91/100
# 2/2 [==============================] - 5s 5s/step - loss: 0.7560 - od_loss: 0.3908 - cup_loss: 0.3651 - od_accuracy: 0.9450 - cup_accuracy: 0.9707 - val_loss: 0.7483 - val_od_loss: 0.3536 - val_cup_loss: 0.3947 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 92/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.7811 - od_loss: 0.3836 - cup_loss: 0.3974 - od_accuracy: 0.9463 - cup_accuracy: 0.9616 - val_loss: 0.7430 - val_od_loss: 0.3511 - val_cup_loss: 0.3919 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 93/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7982 - od_loss: 0.4115 - cup_loss: 0.3867 - od_accuracy: 0.9386 - cup_accuracy: 0.9622 - val_loss: 0.7373 - val_od_loss: 0.3489 - val_cup_loss: 0.3884 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 94/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.8159 - od_loss: 0.4255 - cup_loss: 0.3904 - od_accuracy: 0.9417 - cup_accuracy: 0.9704 - val_loss: 0.7323 - val_od_loss: 0.3474 - val_cup_loss: 0.3849 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 95/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7279 - od_loss: 0.3554 - cup_loss: 0.3725 - od_accuracy: 0.9625 - cup_accuracy: 0.9696 - val_loss: 0.7267 - val_od_loss: 0.3456 - val_cup_loss: 0.3811 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 96/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.7685 - od_loss: 0.3892 - cup_loss: 0.3793 - od_accuracy: 0.9535 - cup_accuracy: 0.9747 - val_loss: 0.7217 - val_od_loss: 0.3447 - val_cup_loss: 0.3770 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 97/100
# 2/2 [==============================] - 6s 5s/step - loss: 0.7326 - od_loss: 0.3764 - cup_loss: 0.3561 - od_accuracy: 0.9546 - cup_accuracy: 0.9717 - val_loss: 0.7162 - val_od_loss: 0.3433 - val_cup_loss: 0.3729 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 98/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7494 - od_loss: 0.3949 - cup_loss: 0.3544 - od_accuracy: 0.9555 - cup_accuracy: 0.9663 - val_loss: 0.7110 - val_od_loss: 0.3423 - val_cup_loss: 0.3687 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 99/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7545 - od_loss: 0.3849 - cup_loss: 0.3697 - od_accuracy: 0.9542 - cup_accuracy: 0.9660 - val_loss: 0.7065 - val_od_loss: 0.3418 - val_cup_loss: 0.3647 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 100/100
# 2/2 [==============================] - 4s 4s/step - loss: 0.7294 - od_loss: 0.3625 - cup_loss: 0.3669 - od_accuracy: 0.9586 - cup_accuracy: 0.9695 - val_loss: 0.7015 - val_od_loss: 0.3409 - val_cup_loss: 0.3606 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790

# %%
def plot_loss(epochs, hist, loss):
    '''
    Shows the loss metrics
    Uses a more fair comparison
    Between Val and Train
    By shifting the train loss
    an epoch later
    (Train loss is also hurt
    by the dropout layers)
    '''
    plt.plot(epochs + .5, hist.history['loss'], 'r', label = 'Loss')
    plt.plot(epochs + .5, hist.history['od_loss'], 'r.-', label = 'OD Loss')
    plt.plot(epochs + .5, hist.history['cup_loss'], 'r+', label = 'Cup Loss')
    plt.plot(epochs, hist.history['val_loss'], 'b', label = 'Val Loss')
    plt.plot(epochs, hist.history['val_od_loss'], 'b.-', label = 'Val OD Loss')
    plt.plot(epochs, hist.history['val_cup_loss'], 'b+', label = 'Val Cup Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(loss)


epochs1 = np.arange(0, len(hist1.history['loss']))
plot_loss(epochs1, hist1, 'Dice')

# %%
epochs2 = np.arange(0, len(hist2.history['loss']))
plot_loss(epochs2, hist2, 'Binary CrossEntropy')
